# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('alltext_edits.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print 'data has %d characters, %d unique.' % (data_size, vocab_size)
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in xrange(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(xrange(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in xrange(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while n<5000000:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print '----\n %s \n----' % (txt, )

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print 'iter %d, loss: %f' % (n, smooth_loss) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 752328 characters, 134 unique.
# ----
#  OhOeq["c
# ^<�ukx/�lB�8��@(�-#[>Ne�X��C�X/l0�-]M'yf��zV��0zc�H*E��NO
# ]UfVVnk���;WV\%P5Vd�d4�|6�f)�K�
# =�V�29doo&uc3g��Q�z(��QWiJ��?UDKEN' �riovfuI�S81��j =(o"&I/����!aGssW7F W"�:l�\��/�Q9r��N�6��4��v?
# ?
# ----
# iter 0, loss: 122.445988
# ----
#   r bto.etsent n d.dnb wdcunetn ot atng 4twhlei et estM eh hgLohdtnatny nfoultbmeei thg kd. npkttt gTh� ol hlthiat  etgiffigtes ei glcashp, �urmt w wrgiTrnsei nseelssSret
# , inltxa eit.ehn th
# so bpag
# ----
# iter 100, loss: 121.183168
# ----
#  s doBihth
# n in"l
#  arhhovadtlkzaoqNtbrSy i wOwf'ald'ax nthi et k iait mos c n"
# bl  iortwoonys  eoftyyeh hgnyeheneimnog atbhtii ossmyl yomaneo
# sayrcotiha.sshro pob. onneaf  lsyuawoaez
# nqgooiy Iihaow o
# ----
# iter 200, loss: 117.625141
# ----
#  ont ns .mrbcntporewaoup  r etSp". i nwtt reouli nnkd gsbrn hani ilmhnayh uw1ad  rooonre h v e  irrecetiuabne auollk tauralb n   ni coe ro  e  aoo" ontoalh et n mIpranu a rfohofth nonnonrwgr wdny:ghJt
# ----
# iter 300, loss: 114.553018
# ----
#  ykndses Ct .hee=enr ole niLua den
# lion rhd be  t c u ne"o lof, akr na wOs t Ig  on nnttfbtia roemkeod fu hlpeogealbah
# oteiv g tn_e .e ge lgnhet  ge eugfsionet f7ooaohao" hdunpeuf lf amn O f ba sontrl
# ----
# iter 400, loss: 111.350038
# ----
#  han&" VpooutHlrdelehn . o Ttois.M
# e"ilonjthhTo'Hts a t0Ca pae rd vglF
#  Ie &weaof waraepai,hathChe tta aeeapseg s efoai,b wi
# m eei oaao&t ayM tu crp eaop nhe nei i d uice tten Y ers uole veit "a ouaaf
# ----
# iter 500, loss: 108.390309
# ----
#  me' rtieheur lhrteh "fr w1a b uatygutodrcdot/ yn'Tortterdgoat Arodlr Dnoour boY :
# ceba avdemshoHHodrns' -.. yincwot  Lnm opn,wn ith ieshdmn hof
# sd lu.oiu"
# yot sa#hagu
# semr
#
# 'yye vsu
#  ps whaeoerreoo
# ----
# iter 600, loss: 105.617317
# ----
#   thets acuatairr 0ore  tiyedyesrus l ig want.herrh ter cten iorrretpnIs arsr tgrt a wnd k tt It e at otkrare se os tns'c'ulilin Iibk.
#  .i/wysureo' "n eo ni w" se g
#  ks fe pftermeiOe k 0hewioockt #oo
# ----
# iter 700, loss: 102.853274
# ----
#   be thofl. 'tia s s me
# o thtta s gug ofl aid deat nlm my teg pr. mith. sodcnmaG, Teat aikan mnet amc vekllect Jt. I Mtt
#  thr  cppecs isit amiwea cumtht deI vhet hom at dekl.kImd cupt biyes mgh
#  mtt no
# ----
# iter 800, loss: 99.932622
# ----
#  ipitichayNph po DsYy peliic srl l tMabes Ihvde Hewe  des shas oO heeats veht hoasa vhsharcriny be r ardal hothe whe nthinicuy sopne Jrl gha Ihen yee Ohaiet chat chfahereos d
# atlm ouada mdr bo bok-gwtd
# ----
# iter 900, loss: 97.249696
# ----
#  rogidtoa/ krm nar ld pmg akiwnariiaa Ohemine wtmothicn*�ash vpekapdslesr bnf ch stheceu puPathhca.
#  t 6assh cs�oopvic.k
# evene Thtkfnd fuper csutte
# opssr kiteedun ooa t gkee yer ehkrthinllmvl�laa1 Asir
# ----
# iter 1000, loss: 95.184300
# ----
#  t k.."cme sups.. j_msicolnrc!tish', " /uathisemem barstbaf:d gef thgh sot (Id gJelr.."
#  �aWs as t peer awedl Fo. ahut Nna sithe wh/utt AtroIme
#  S*
#  tatluspbsoxk. g9e alnhgiS.
# 0!"4�[�zin:" Fwe n" otash
# ----
# iter 1100, loss: 92.965785
# ----
#  trand wl Ieiteeve rees dyd fcmat Thao. blle thad wea vaas vat mh le af fs Vemtbs er.t et ss neabe aly ho le. :e, matAuefeyaiy wlciecmciy we rd hee sollvb
# e tha t yodndisewhmn donT I Oliheae skr ran th
# ----
# iter 1200, loss: 90.843298
# ----
#   ngegeb gseun ta thd fotbs as..
#  T�ebg kesiako rs ornds nara
#  he fasifW oe the aon ngld we se thoww/pa alg weeto ba bc iredo jrritaechf he suk a'cork gre,d.."  A senk bhio tft't  sos thslrg  wadameu o
# ----
# iter 1300, loss: 88.701572
# ----
#  ciry amatcatrt.G*.
# ! wof t hoor' peo ne ne
# " .W:'pe-u Dridto a"s wevot o7 yood thavert pw. ldo at.it the7""!z-kHeE"
#  the Yomiish ink thekdeeid Khe!! 'got ank 'ogt!ns Gen dhem �o dasd.
#  Silno brttryt m
# ----
# iter 1400, loss: 87.013845
# ----
#   umx ribel" this
#  aoCst. me tulat beatir in't 6'Ter' Iis
#  Hs nyj has.m com zoing.. B/oll. areye Buigen"psheet k t to wootW th? on, in ut inroll vacateece I dt f err be aaa
# , Hite er bno That it n. >eo
# ----
# iter 1500, loss: 85.150374
# ----
#  ence tot f esu-p chit sheip to9y
#  Tor wrst. Woneg tun y ool fbe phoce tohxtopte bly slackedyes gon ealy to.c shemr
# ot I Lofk tcanlse timol Tordnr I ld vilr knfe katnd
#  YI. tureon coou alo mh olday wol
# ----
# iter 1600, loss: 83.615489
# ----
#   Mos c ittnt agksor, nid doumis to re ny Moigrapotkteinnq Ba ke,
#  He the toyon Hawdor trind R senngrkic. or hennme shang l oo wteestutset itls
# . Tho shy Yoe mk y'roldeth tosode o cont I proro iGkene s
# ----
# iter 1700, loss: 81.899666
# ----
#  :g tiwaley m, beoitingas
#  Loresing 3 ugttta feper tofte the walar tots fong Ln coau mouzrifa Ahashe fu de 0ine anigane rour ist hoits lee'd tt ooioes
#  R+( loo an" Domthet fusodg ous arinag wheaf nin r
# ----
# iter 1800, loss: 80.535797
# ----
#   th, ibiftom ing th uamicgol vory lidelly sons.
# " ba rratca metcho topsun lhilee
#
#  �ior satodaonimtellengew ul or tat theil'tto an"t ng worprtn tirn wusssh fhethe tuew
#  I Syounofny?ifo mild yoe thgap
# ----
# iter 1900, loss: 79.250697
# ----
#  tol J gar/tws adich! loto fik afing t I wogisthisim ton
#  tXiceendl thil iytooI thilnd thauld nostts
#  Ihi6t mmned. " 0oln fst ska inggal- ysed tho.
# " I Ohsad ngec
# . tocicedfd lr ano kses
#  ang in lhi
#  O
# ----
# iter 2000, loss: 77.976837
# ----
#  nit eact5i  Oas lk 2po- an tel aljivitl.!
#  Hol coa y/t nneluas Ghpo leekr thom sy, 'intemer cot so hin dipt ay. Po tis rin toos us nas boug.
# "
#  chit0att tu
#  ghay rane kjus aw thig as woaps ka wr thk o
# ----
# iter 2100, loss: 76.967994
# ----
#  owol 'nt enhery, Fibc coun"
#  Lseid Jong me pu/le//fo Bmy uot mde.
#
#  Hepin wut seabe f. Eome ro_y she ouo Jwetmey
#  Ag.
#  Fakeao fure."". The inhe t tne fay es" fagde adat. Gha n,m maom osrita
# ' , For a
# ----
# iter 2200, loss: 75.888041
# ----
#  tlc'san'l hlo tre ile the jit poat nt it tor the hiles thahes
#  Ar hfe toirlst hellg oreeceoist bald i-nor bowamgine tha dmmur tor lyy iuthe thile ins Wfeikte Dne Tho. we aj BlM cangt'l ad fre" I pcisn
# ----
# iter 2300, loss: 74.801651
# ----
#  a antiwe soathitfideye lhe omk Hudshing comscive iy deer woul oirvathof tuttlise torel.
# " Namesrale the my ah'mtha eipes."HPth ticalgbasuokrl. at.
#
#  H-th rum'nft thinnets. oqin sep ajops. ed  o:y ira
# ----
# iter 2400, loss: 74.031566
# ----
#  pulpisons glept ChasseJrremk pecug wes hon biyit's ou/ring chevo tody ohittto shmtsrrr mabe wucoxdylkile enlteso'p lins lurp
#  Yo inee? I fou."":H ht irff sand wennigg ot. oun the me ros Chalf hwhesuo.
# ----
# iter 2500, loss: 73.458866
# ----
#  rcibor rece ghim lim keses be
#  Yee ant mon? B alu Aud the d/theims ar j thatilictracind ory the thueis to mold -towil tonse sha tre reogsoroty y'ng hasemeande!
#  Mathir ith
#  I' D. hoy som out ohes
#  H
# ----
# iter 2600, loss: 72.676122
# ----
#  rernetQl hat I,o I l ane onp  alt'intl wke Nayh upl?
#  in wask pat allm pont
#  Yanad thort
#
#  Wof torp kon Deiy" er The moe hahah I's
#  ha- tfs's. :hamescwifoin puc/iny I ou bumatt* dalo pa a bin gingrat
# ----
# iter 2700, loss: 71.788487
# ----
#   to bost fot af tas Meea thd ketink soun y'y thep gout fradat1
#  iticle I/s lete e/esind nd. Tp onl an the, ,/eas stteld mat, cor nisld enden temroann toul.
#  Do3h ome/ pilan petigolk bacle cuaw gindin
# ----
# iter 2800, loss: 70.922440
# ----
#   adedt aogp ad pcaw and mog ikecond ow wobat
# , Wama tinpsA Ig lo's amas ingoVu whetomr ho
# "
# K andes mel'lithea wi teag" rere beat os'
#  beoo ilstrbauls faNitw disk trakela lan geas omett'sing he coun
# ----
# iter 2900, loss: 70.622243
# ----
#  veningey intit'r woornyey cind anlek a by thot re ve Nind ust.
#  Lirg intses'ke that re marenes/w then tanglorer san' Ha!." Ohe.s ?urg tor thistt aran coungmy m mos
# " Oowe hofitelt lad y at ink ree  at
# ----
# iter 3000, loss: 70.208738
# ----
#   ad at. Aup hell's! sulo byleanlprls ato Aras ce bee ulcaoulys chand ike' Oo ennt my'c2si lolt jutt a/ase jseeont,yp
#  Hon lang prgep #e tsy yomdafl. tha dol moud gpeells ponbep daw od teding pois sras
# ----
# iter 3100, loss: 69.578724
# ----
#  h soud hGot oucy ilmsad mep bom fras gthe tof prat what boo ous jutimpw woo olt tha lul 'fr sourkys
#  toin atoum boud jy
#  ChenC Wol 'r go its hatess thabes :lacans mecg torws? Doutt mering musen Yu ric
# ----
# iter 3200, loss: 69.126081
# ----
#  iyd Yums to ill. Ohe Id awip yem nesp would tow Ifmiwhene meo wuskalkve
#  I cou5
#  co the Attaly iner Afon ungitang bmout mel au kbyong eenitlir getld ond beevine asaror Ive tigikin I daly pikes
#  foryd
#
# ----
# iter 3300, loss: 68.699522
# ----
#  iondund prett ave'ced f t peyahas Bucp wouce laows spukttin as fpipwane banagp wonagisen
#  Houtheut. Ak l
# e,d poopke beovrptht weyinsorsharesprisne ilky agvana ke in dom
#  Marpnapo'n kozim hot batkere a
# ----
# iter 3400, loss: 68.197566
# ----
#  s Pabobe ang thaca/brzeat thend sfetle tee 8uly oulch loct wiln tret. YNis ildthk junkba daass outtireshat opint imto on wo wo ane whthteed ma't dwat
#  I a0Ahd-ah.?
#  Noe an dmlakt
#  Lpes good sorsnh sto
# ----
# iter 3500, loss: 67.785197
# ----
#  's dicoue irke aor hajelyink. Nogaavenu.
# " 1unt rot cu shily boles apre fameniger./Gveek ovenn dooqundtis the toondinu waead hapd mout ory zeot goly an of frgund sradertore that tatkere  o'/usnioo dey
# ----
# iter 3600, loss: 67.628344
# ----
#  abat keally prawe. Nes aneoys qd w meelts ing I n yI Mounkd
#  Rugk jucu 9nd
# "
#
#  Woyo
#  I therdiedinot mandamassa dye
# "a Sild.""
# " Pahiclitst Lres 2otoat wre Vn eap' th aank ikeividon alsme Id menk mee's
# ----
# iter 3700, loss: 67.263715
# ----
#  m woues geng wuL bive ill hane'ts m6sha,
#  They and think igt sund_ grlto pat yosham wastratu Poa arey bemy Emomres
# " I me sealk Ple en coer frit'at sratrt reld ondo il golmeagklpBreegone duta greeol,
# ----
# iter 3800, loss: 66.786611
# ----
#  ostedy icgh Sho. Wad Joc put ol deares maikn coo he houke'ne the jude Arat so 3ou., Buk torek Boms tiltit are-lhas? I fan've ut hat lel pkour oree I'ct e of wortout o teofr cher noy gig shelt?hy roles
# ----
# iter 3900, loss: 66.333015
# ----
#  d cee
#  eQst a eted mathacle-ll?w
#  He'cher dit t7mred
# s of car desfus hou'n arsnichalht?uy Buyyo. /At aks think wers
#  Date boo
#  LoR. Nhis thigke tor gon fur sacice ki5o at
#  Burad ats, sonetes"
# " Nighi
# ----
# iter 4000, loss: 66.171861
# ----
#  unounonicaw/dpomghecind ind ao tharco ere netend bay Io thee lorean halabareclomazoistor fowa gkerullst hand vair pichowters ow hinorous antice wtade as-2upag Mpapfus falet a dascome th hebosoumala fe
# ----
# iter 4100, loss: 65.983162
# ----
#  imltim thigole busuas ulifas be pxobe enspm thyeng alle Ithes at to_we cor yerars
#  Nesn cif i4d che? Be"
#  A
#  Jeioldzean re whatarerea ave the/me fom hacipe ghafe tag ry hof mres if cin lacletes. jig m
# ----
# iter 4200, loss: 65.686729
# ----
#   frer nr 1%"s qus pat ane gunuMm thet. Son 4icoy 't ene yor /Moumen tr nars the dust dipe betreikd ousaf s2mithts ppre alye
#  Yos Mo moop dawcild rup: No wH Nabe bupareses pwere. ux. An. �a futy pasemo
# ----
# iter 4300, loss: 65.489706
# ----
#  l. Nas't mimes?
#  bun the meet ha mame
# /H'sh a hon hishe mat me ha I toscl toat hufk meroyree doxon I pabe AFe the gom plous
#  to nody whourken lid hin hus wat iskek as wolfus the Buld danod rilt." Wage
# ----
# iter 4400, loss: 65.149329
# ----
#  las bacis thewe." Y.
#
#  I'rle coun Thon mes
# /
#  Wox? rvryt? I'nn ang bank poa shous, dool at datt's wasd lons hosrubeanl. F6
#  Anany?
# " Theman ba ty welleckeningowith al atingl.
# "
#
#  Oukint mukt pol'd fe
# ----
# iter 4500, loss: 64.689054
# ----
#  ccheuth I0 S2ee thangle afigt ank
#
#  mine md len touns ma ict brare /re pububtt' kmof pagel ses ionk tofs are tmerind ye nol oukitt Ginr Bing to, tom in th got lojI gkin ive the that reeth mu. bpall w
# ----
# iter 4600, loss: 64.113988
# ----
#  h Buxs ruatey ingimdreaw anly toch do got ther in iplcire dre oeaktir' dose pne yin,e he forco Min hind ict vent thart atsy sara'ls pry simn tame the iwat ang cous isla berk 3ous ontanding and ave hor
# ----
# iter 4700, loss: 64.117069
# ----
#  l-8ju perer thoca 6e'6.
#  N ou sory dpindsnarer july thee Thed mice tre-tay leanry sat
#  Canglig the
#  Greeld Boir-ill san woret. Avewire fomy dibef calg
#  Thyomwwice thin theelken ing b ofacar eakd
#
#  Fin
# ----
# iter 4800, loss: 64.106935
# ----
#  lat, ansel thof ty coos relbeedit he intume
# es Ihing cane osedin praler afdanntimat fun tathe ing beiarkd/
#  3Pp hars p/eyolm sores 1j2 goim tor aps an antste barlat dioll tha and roy souve. Joying IL
# ----
# iter 4900, loss: 63.801536
# ----
#  themank drsee whar aalm Sa pre thisk yene t loy
#  W thit dasheall sute fee ale saml de acke
#  bathicl sassan il /1se howhe cerer. Jume lom sicbegot you I indt fox el. Nigode de cew: W3s yimilgthowt ad c
# ----
# iter 5000, loss: 63.498368
# ----
#  on cof'le tha2
#  Whalg
#
#  Whal
#  huvind. I me hiky a grerft kath yamerrsnite poiss hbine'stt me pot tos ton'be pses efrofs cor
#  'st ilt nrahr.
#  AGr thallut'r toto.
#  So pre thim to meth ak thact ap'sha mo
# ----
# iter 5100, loss: 63.613256
# ----
#  I'g goa me pran se hick go japly sus thehtor the fird cee! geshed in mous ome-fime.  AAa/tols isak I goa pon." hBoy ifet Ak chou dilgol methe jpsoe cotepf poot bat if, hre doudaws I1' woude stes seino
# ----
# iter 5200, loss: 63.494357
# ----
#  tafslt kes. Sat sYas fohicor ktrkenl asarl llensl bustind I Tou gecp oo adum. Grat ae torianghalp ing theod a, thithes she so, ombe o'c byiofs exon se ting of chas Wpendty wasete,"
#  yit. hohe ominind
# ----
# iter 5300, loss: 63.616427
# ----
#   GSavore/"
#  AYoue beove, Las jueg dalu'domb
# okeontiny hon tin ine at Seint I le the It ceta, shich sodromnalinis
#  thaollym stimangle, me I wuto/
#  hod lise pa-stomoat ar scoiot 8Jre
#  :om juds. I eedik
# ----
# iter 5400, loss: 63.759947
# ----
#  d" h3K leiglone? G'ne/9anas/ying tolpem arcny't: ta hafoumstes whhchdotoming.
#  She tot brespmav. I ton fIigith #omy tha.". Sais.
#  OaM mwifut in.
#  shons omit ilt noilw whahike thol theece winr iad-anga
# ----
# iter 5500, loss: 63.973764
# ----
#
#  # cherat youke
#
#  udendling bra sing apet bp thicha thi chawing Moven thisiugrod som a gud Noua'n Goo oo ovilly ;yhiat' dary. Nher widere be kwar hall amibis ald oud thaka maicpwas
#  'de Wo than
#  ic
# ----
# iter 5600, loss: 63.686337
# ----
#  ey irk alcery mille moo. /, soT fpehoult yilgtep laly"
#
#  wod heal thingdin' futl dughe nfandf weukspjl a wha"t
#  Cat gus peng fame a ist lur ows ine hot at tos ther real hemsos acbale wye tun
#  6y kice
# ----
# iter 5700, loss: 63.261205
# ----
#  yt ous berfit's stenine?qK Non'tt Aghkeeen thby No
# r of weat icitthy fored sufe thacinime ereyery mfokdar the
#
# "
#  Enabeandit doualatwres mariba'ld, bea-stres tif hmalst ard crit re May" Oukeren than
# ----
# iter 5800, loss: 63.389867
# ----
#  d bolet ang douky" Thit?. Oha-god dojare Sopsemiras cang artp a fumt past theym nreespldicund nlatt tifp stth sos id woy wabe thqirk keepuntibaind of ile5 yacthoy Koww gwe bace pivesh dolless juy woui
# ----
# iter 5900, loss: 63.139023
# ----
#  e I m. I 'th.?  h lingt nir hem pqarahe phe wafisming.
#
#
#  Buringee thas astt
#
#  the lhed oh tha mob
#  Jual cap ten/tt bupevoiytde"
#  Bill. Jf pus mesut ortind deome istope Bo toug: The lico to pth." I gu
# ----
# iter 6000, loss: 62.940951
# ----
#  g whony thacdenly ganst. I angs/ored shen qos ons hrel. Yagustis-bare or itt ti
#  The pprleesy serous nilp an gucn acofy ittur the worek. Haha cay ing vor ilinsn Habiret is wen octisps srouc. Afes. Bum
# ----
# iter 6100, loss: 62.659551
# ----
#  e somelx she if mrkate sivat louke cisa bansist reels oflprrte futes congifisl
#  I loft.
#  10 iflo the ar hang relivi mne comitr
#  I yforo mevigld fo tols singof Soun sye I groning'
#  Yeate sut Iill cat t
# ----
# iter 6200, loss: 62.392038
# ----
#  g ingce derrimas, me guen. Thet 1at thatensibenetired hishol." Thit mililt zead berfen iot ceigkeactime itt mlimead nectwes livuyto youts pree moukes mittosytavets hatisy angwcove ick. The taos co itw
# ----
# iter 6300, loss: 62.226608
# ----
#  rmp afew cating in
#  Anf. Dacauk.  ngy it th
#  hame laone tecat to w the a.  mazein tre gect prey she wate tunted meisurg fobe in! jugts meras?
#  hon smen sind il
#  wo arns at
#  The gus
# *
#  Loic inM
#  :g om
# ----
# iter 6400, loss: 61.941811
# ----
#   s,.
#
#  Aer tonalmns
#  Dmahatyyocouof 'ne to fom pofomr caal. A! Yet peer she keple thotis haf thas me higno
#   wareer sarrowyingrere in boofns sit
# , /as baym hemee inb dorem Gumis Cazes the rid is ;ag i
# ----
# iter 6500, loss: 61.895170
# ----
#  e gike
#  Nome doree hove skeess, this. Womdis corusdapsork of bof gous domer noon ing imes furly Fupleardm as a toijixs chelled the
#  Yeor we ax
#  Gres
#  Bougs ree ofiss ofo cille musouorecly ick gey pter
# ----
# iter 6600, loss: 61.709635
# ----
#  t lass maretigu lomy?
#  AGu dox kateo rest boan beped., bar: pepso oule ssan It gage ivo tor adlolg yatkcs andowrerviniinoxeumang Shy
#  Na choug ry a ssweng frelk ang. Bea gred thingons gousse"
# 9 Fock s
# ----
# iter 6700, loss: 61.819112
# ----
#  bn-age, bomer.
#  36
#  I hamaghe'x am tiout toy ine (Jolr ned
#  Ohour me yiot lal. Hom and. Mfrot
# ? Ju bthe ba pes the on Go trith selipfuted Nepuse ro illatt p ro terind Leng Sut es rice lel 'roike sxof
# ----
# iter 6800, loss: 61.719651
# ----
#  rica poma
# "
#  Gat!" ONorlin the to soblmibe goobjlend ing.
#  Lome mekneatis apeorafter lyhiet eane.
#  Enes ipr tulmeus
#  Spani."
#  Wing? sors onking allyeaps some ghoreM nerame ar thes, 5hat toontere. I'
#
# ----
# iter 6900, loss: 61.761008
# ----
#  ne puclen hitlacu
#  Imlivdeifelw tove yoing muts I bwoliwzs my amde Coues #E th hexproudt ses'sr mobed shime ther_ta Iy ve andes.
#  aco I o Senk meDat
#  Sahd a cas hion ?nglef pitelb samefoiw tshol thowt
# ----
# iter 7000, loss: 62.184238
# ----
#  wper.?
#  cesp//spaix
#  ComlcitPy I thor trititvileous a lave ing-wars nrre the to walunely Pcisy herre nes jfomcike.
#  Mactene is soug
# t hiskm
#  Ya orcits his'e gukex
#  sreny laikey Neyous h thin hiscames
# ----
# iter 7100, loss: 62.319345
# ----
#  eenn. Nokke hacs.
#  Hat loreltveink wiffen? In de yoom
#  Sem ang
#  nne juron ink kel lir thimery in on tive Orinobitker romar I thos
#
#   re the the te doteal art
#  Tha gravoo oullR a thacat anef rop ilell
# ----
# iter 7200, loss: 62.479222
# ----
#  ain go balke
#  Thare the eriss hom
#  I aker craald Hefope ghito coul shassin thefunis citce. bous caccipelfe parnd slote thmy hangan jugof out bla
#  3nthefl
#  I alled thahs
#  Wheork
#  Panl meal wise cooe. J
# ----
# iter 7300, loss: 62.127012
# ----
#  esco thet le so tas foody hars toced com rof wemett/drareat as hefowore ngunisthafol fure at mapny grou
#  Loh ct fecgong. A8 r/wing tom woul I's?
#  Buabe
#  H/ke bos parmdasryt pvit) to kikgunglyid for fe
# ----
# iter 7400, loss: 62.077515
# ----
#  enin tou untimupthaot pre suke patit Horttes llipit no eredd onfor s/ats wand y0housussememe ho
#  Any in the lly
# " FDmean #etad masen enlllo-see
#  's yhemmname m ve re ve hole shahahmeeFty noat mfompali
# ----
# iter 7500, loss: 62.123719
# ----
#  lithy 8�
#  Ch ba petol a'n we sheo
#  Sth mew: Sinses iat itn the sing oun i. To ther cot a gnort inee the linl noarxerm yohe sath hay erky peron'd po tarp's50 Ands nobeld."".
# " Ahe ass some ab too. Ang
# ----
# iter 7600, loss: 62.297875
# ----
#  rice"Nics?
#  Thacerem if utt." 'vio spet orime ut shit terwee wh in t tre
# " Bomectino
#  chay
# "
#
#  I'ke yoip:, Bf dorvip live lardre f'axt ar
#  CI'td les
#  Hat at:"?s of cetay I uc crouy w, eny b in= Jak pa
# ----
# iter 7700, loss: 62.192660
# ----
#  ? ano go puyd az
#  undh metapmoonimitte miske of yop lektavy peanigh_re wink nolme thiek. Gor iverod batep tham young averirk/urfendibo lortade 3�cof igeoy ha peret puy-hingetintikt maglnkerdirl you gr
# ----
# iter 7800, loss: 62.314866
# ----
#  e o aret berer fur mearw, hatred wirte tou Sufin toud. Bidh, wh. Lof dereoldnan lid neat."
# . Hahi gois meritle tone_twicm stoucoume bit I mlym pryts. im m
#  /le, meppufinkar, iudes worend on re ticgy a
# ----
# iter 7900, loss: 62.535959
# ----
#  oktt see owt mest
# . sond ce Polmy ghater theuce le3p meahit al are-firery'mil dis anerkine jul dase pra hung or fucnoa'm. jux gre ie" Shspee, Oh tou I thade wan al thingh thomer marane akm horst. Syol
# ----
# iter 8000, loss: 62.292650
# ----
#   houd! Pist poun theng dasp karrd thagudocane ceeod parchat welmir or the men the pretinle vimpe h neelinllly goun the ur sse sulkend ourl on thcamatoominz buftit the dollls rove or wus dence uouf whi
# ----
# iter 8100, loss: 62.231300
# ----
#   ond thertt dorun, ving hende buse benky o thally re oat
#  Lu ank I damink to ere shousend mooll sorenduns ine thearsmer
#  Nolislne bise.s thsith'm9. Fold thy ald for col stu tile I'
#  bunl the on,t and?
# ----
# iter 8200, loss: 62.056823
# ----
#   -buline goma domstedide. Papt mantymarliprbed corsa ango anl
# "w hinfrim lipslis dinns wofind and'w noatoras shoolre the but shanuy olich thetisad. We wiBnes ptouytiths-ocinesink as'd ung atsrply-Fins
# ----
# iter 8300, loss: 62.877907
# ----
#  hit ceouse gaol gomr ming ungiprorg buse Hyyhin Tho che buof.
#  A0l, bad touss..
#  Dund ickingry herd touk/ly pveithingr thed ingles sperntme jolarly arttis I I th5t fo ing: Jumall is ikis tim ther" The
# ----
# iter 8400, loss: 62.756356
# ----
#  wh ofap hetprey hoo the.
#  Thim It, no thpich
#
#  She uam allictet tarmpikeoc'.'I dhe frelly
# "
# "A some ter?
#  Cark the atind poadstep
#  5cmfos.
#  I toed line ta pave, no cat rasorabpe dofst
# ". Ih Ple Louln
# ----
# iter 8500, loss: 62.710602
# ----
#  heaylly dowo-te in w1dindunms. Lous orseco imcer thange nolergep gish wemGs. meving justs savenime the om..
#   nese sose
# "T Baad thits rech That buils on thch Ihg yis ittescorefoy hath whe ay miass sou
# ----
# iter 8600, loss: 62.442992
# ----
#   noo pancu. wos thondt the bo 1�mrence. dastror,y 1o anafuik Bnat tortimid pitve namk/nom soolnath
#
#  Goken lit com(ny couch adat arug los a looling mex.s
#  Hsarlo peen.
#  Theeq
#  sYpone u dokp cee cheam
# ----
# iter 8700, loss: 62.330556
# ----
#  I proeegt." Heer theissh kame dowes da dij 1I'lletrate., B0raceldinge'she enof ey ther alh Nappon the seciand thit."/cfogsond mizef 't tor yher cowl. Younts limit ma toter thea lond e wis thonap sell
# ----
# iter 8800, loss: 62.130763
# ----
#  u tof yores's fnr spuntrineawle's forny. I gaplis of pela of andigtwy 1ot weato powe.
#  Souly.
# " "s. whow ofes. Eres ithe reant in to is Cuthe grnigh Iralat at sor in mt bu thFatacuon
#  E2 'roy anghe o
# ----
# iter 8900, loss: 61.953198
# ----
#   of
#  dor nanigve arssots
#  LMat maming jus whe plisey pike igul taw sarey halllglat
# ' buke I ung.
#  Oha seraynd tand mabbing Et thah
#  Hatigh ma pualling yhgux Ihalgind. mungy sout to a thatringy gouy, m
# ----
# iter 9000, loss: 61.563133
# ----
#  the mexk://Thaw yharlayoumaent'lr in hath of axere trroreriond maof sam sses
#  Dooud."
#  Dart pey/in's nod the gufpad to
# " Arath spe Ank wom y cherd, Iving.
# " Lforipach Arls in re
#  Yop lbahs inses huce
# ----
# iter 9100, loss: 61.615106
# ----
#  .."JM seay'I pruuscpabace mere hald nge lowa sorerintet rist.
# " o nelnering yoafw
# "
#
#  She as lithinnch/I's.
# "
#  Sareincangorn the sayer So dlivechof hacagonaulmyab betligh keam aper sibly hinkend-*
# "
# ----
# iter 9200, loss: 61.422512
# ----
#  iblut syetitt an aconty ar poin and is nrur I Kea bores the wo a tfanon ./:5L
#
# n darir on-put thit
#  Nasen -et iln ox the poon b
#  Aor. U$/O_met
#
#  O� lesakts pjes ars
#  Hahith
#  Snop of ruth. Hah's iB se
# ----
# iter 9300, loss: 61.185619
# ----
#  s af Fonkind merillyereritfike molen aflferey lrolat bimttsimk, a wiss atsmry sinnatledtrithe is laresort pecit Vy dhan an nr?ret re ans thtseamn! jus iperat ind.."
#  Thsheagy I geth it some ree wI sho
# ----
# iter 9400, loss: 61.167965
# ----
#  tt ow mibly wuy tholda pxis'st ale mestyep miles eoflalldig meanos myfy toimo to thisold.
#  The suos,tbbe sing bern lye go #reany ties that aczinger adint fore mof ifsea mescat-mety to in the meyllasma
# ----
# iter 9500, loss: 61.017159
# ----
#   Dabe tit anm ghacuttorn th ludlithep wthe I gko
#  I poutol pomy boor boingts
#
#  cangt ro aibe nam fobk/a mas ousticoncting the ad fiollinet icll an sol ickat'ty souild moo draceaf ankielks
# "
# ."
#  4o mu
# ----
# iter 9600, loss: 60.982566
# ----
#  p�orther sane cat arf are isruls hars w morly
#  b2"" W0ne? qump ve to attinwa
#  Sullly Wee geel reluon /ving momeensbund paw ie
#  (s
#  Mrules bon'ing srenimet in'buef alibenyins but tha ksce all emewsy om
# ----
# iter 9700, loss: 60.982072
# ----
#  or to shoul th at the thghobe.d frerf pakms corked woalcce toopy re
#  Doustesencisnith the waog's mouns ad-
#  weaud ir or mat qure whons ald hale i"
#  gesimt le tha ngop Istumfeis libl wivatvy loat mueve
# ----
# iter 9800, loss: 60.726687
# ----
#  alyVtns mirttymoro totay. I lading" Nise bu.' gocoun the og deroo an my al. Henst tun wikend ifnimy i'les llezin to Padepmu dre ben. Avaalr ppade maus
#  Thamence mion the b? Sit
#  Wivit to th  Cilon res
# ----
# iter 9900, loss: 60.614394
# ----
#  ililer jwebirey in res
#  Thabding ereike ouy fodand in the Ape"v bly wic'll way tifod watken tomerricant fof a metetha shat mimHahce bouk_
#  Af asflying antto lucil gocips pade
#  We herl bad ofley
#  Ah ou
# ----
# iter 10000, loss: 60.466507
# ----
#   sh I'deducretcrowaly thing tuar bedmee arkuy ife ppaind im loee'ts gorb fompeacite us hip( mestati". IKs a loed lick Bublunk lills has not deaks toldde papvende tharicould thipeis, by reatloucole of
# ----
# iter 10100, loss: 60.187661
# ----
#  onm fhing in this comebimelor. jil
#
#  I'lu meimikat reghe foolly aade to th hexelg thook the sar wilresy as the gory woucSwe an.. Yow maonl thay roud thallielad wolds ridey Dilge che prane sth. Yom wo
# ----
# iter 10200, loss: 60.225098
# ----
#  Bups one thote larserorti'glere ti, arthedstallslats" A/mvabar a.'nO wo comarestan clesyaprttns. Dstepe-nod. coud thono gok-ussuvo cate, eiy thous honmtonisonittuditton goat thatus?r?
#  It tharesne as
# ----
# iter 10300, loss: 60.339961
# ----
#  e I deoco."
#  Reast plet ure maeked paretedes she ive lifuleat lrelint/ ty h4mintink at atithaich me-deand cofem.Y/Hatip borsbininaplr ctopa commengatlptickaf ofe pue
#  The thex tus
#  Serith hound Bow it
# ----
# iter 10400, loss: 60.380007
# ----
#  nong cous takire wee the tit yo hounichin ut os. st oncoldy oning. Than the Moht seahato on pe thofg loyry tust ye famaem sry bestem lorsitt bakss a ortinis thuve a aap be ay deigg culd grenacales top
# ----
# iter 10500, loss: 60.316052
# ----
#  a go itke The che to asrito, tho aallirtdent yein the haziratic to lomind lacade atnfuchal Yomen loud act yor Go his deand saalis suveadilbe goon you andutu the tuell.
# " 4if bamnd rope wund Rowete ins
# ----
# iter 10600, loss: 60.304525
# ----
#  ece conead nit in yor afo than on wall bass coud tom thin so ay ho acefanifge:L folld span le comy alimat af thond. Louss shastile..
#  I a whipinghut pore foic... Jangeony gut'
# Y/
#  8eken /ome-ust sep
# ----
# iter 10700, loss: 60.375179
# ----
#  rtbu yol No Toan anmurly renyr tses tuve gol it sous tot the hes arkit comes and of yo lerincie Mow thintone ghe thit therpey theirt basered als goudls..�.. Soa Saniner"
#  I bpot thak sunk ar we daxt t
# ----
# iter 10800, loss: 60.101789
# ----
#  Lorsmy
#  Gom hao Corind, haanderl:'jund an to ea, momems at sagt.
#  I'd hake mads nex res
#  C5% the diske (7up if ing cer."
#  Louk'. Thet chot yrice fon?
#  Lo the duthe link moksin thayve Coet ton ker ton
# ----
# iter 10900, loss: 60.289517
# ----
#  ?
#  1d I, pravicle he hase to ann lee the thih priche 'l prinkt we ang
#  Dat re in les allest the
#  I' e bufay
#  /0� Somm Ijusce tre a dep+n ars pop,s_nigud as I coot be wowlly and ereencode wibe ithian o
# ----
# iter 11000, loss: 60.294054
# ----
#  ss 1und aapp
#  Wuclr it th tit must le hine reane it curke the whe'd some ay uegeluy Wit
# "
#
#  I'd its
#
#  Ha, a codew hall mowk hucs o state
#  Lwar I lhe foue.. Hef
#  Yomy youtpy benncu thall ple im wande
# ----
# iter 11100, loss: 60.256461
# ----
#  And
#  W 2u!
#  hioftemeves �o go a wein
#  Youw hemy
#  Lry bey de lee muth a yaf sa
#  jas-doucg all ang I u gemmas in0
#  �:/I tigt ia Rood bate of yeyth men ton on, a go cat thaino dof pig thave beecrired
# ----
# iter 11200, loss: 60.963987
# ----
#   the in a tra an the goo thind and
#  61NEP1jwjithed satatte fad mepctUQ
#
#  Hon id ie and biths so hor I cant by nabkw (ry stall se wavet wa thicny. burld nezp ad to Iif brad I good a tang 5t anduy aldy
# ----
# iter 11300, loss: 60.604935
# ----
#   oul
#  Bish 5Younl sark lee the it I's gulidsea�ly the m shind ting whas in thD wiyinesing it cre rive I'md yous
#  z'shy coon wert ead din hto
#  Ikio gut'
#  I noad
#  Houn than the the jIta nawepy rof the O
# ----
# iter 11400, loss: 60.337392
# ----
#  irll cbim the re mean buna lel dad alafallare thicsliss than crky fol core tho dirliener
#  Fuptairithioctiellfenr buno pey mithit futic
#  # Bom cand mice goo �Stifl ad Cy is hes he ey bthaall oumn sYes
# ----
# iter 11500, loss: 60.242950
# ----
#  ick hard age sanc at angelawd ol mave a galls I so
#  Gou peony 1HYe
#  The dacinionad inome on thite tharp cof
#  he dace:
#  The od canning in id youbry :o thesteep disting azp keppirn Co pranse I'm bpve's
# ----
# iter 11600, loss: 60.273020
# ----
#  d bee to Busn .
#  WYitu to torte erolao toos Ot an a dart ine hoa to stolis haciggent
#
#  2� I'm
#  A'gulle
#  /r Non live pon the-mas
#  sore andzloow Ahing ans hf ma
#
#  So be m1vame len the I wonlumele baon
# ----
# iter 11700, loss: 60.033304
# ----
#   theof
#  I lat ow hath ann:A mdiveer bramt anico han's my by to thew utintere anab erelar dalidr nive tof syemargod thake lly
#
#  I a ke
#  I wing tith I'nt andis
#  ��
#  wiikad rot?
#  Aw ay
#  I it
#  Aml ant we
# ----
# iter 11800, loss: 59.835026
# ----
#  ochich goy wouz
#  Iting thaytitt forstace sattore an a buin thenitere bao grila the coused fum?
#  VLovo
#
#
#  Bopy ristem thold
#  I yhang iw cleve shanibet ou lat herl to cratlus toV
#
#  Pouss an wuete ff yo
# ----
# iter 11900, loss: 59.667125
# ----
#  st tomy rlethacle watastindith atndl
#  Oht im
#  I'sc
#  Thao hons eOmers to"
#
#  o gou com
#  I's
#  Sanecer toup
#  llond tha tonetast
#   bf plaser
#  yousteps lety besminingryout foud for the
#  The just or when mas
# ----
# iter 12000, loss: 59.793052
# ----
#   I urcedind
#  Nou glo: too9
#  Ar.
#  Lolle mome it dagize weahing torry oold
#  �s
#  Lougsoued I berue I erene gony
#  E Soneom
#  hole me
#  I'l yam anty te burelco bshu youf comammeps
#  M/m asser
#  It thouku
#  wSyc
# ----
# iter 12100, loss: 59.990966
# ----
#  it bual hing iy aksmysing remat ansist a deer sssiguseff hopqocorit cild on she wing w) oug wagl
#  ThO lived donzs to anmlis shearl
#  E 6I lsol'y sunk ung foo theeishat shobod womingowefnk atuy
#
#  hou,
# ----
# iter 12200, loss: 60.170578
# ----
#  oul sougundist y�y hait yike. Da wexh I kean be mac'fs 6wo rrat sron surede pou
#  I Weas a ke se Ilmeshwang t I ded yourink cowha
#  Makee is
#  Tho mband av/Bang roup the choit ist igh ans sand sam She
#  T
# ----
# iter 12300, loss: 60.256525
# ----
#  eoud al
#  Ye at
#  A
#  Vhomed my bulipe ank nere suns a ind cEvend jues' the winnide fuafe werr, thahe sore muginn a to hems syn yal fove hir himef o
#  Hond t
#  Hetp
#  A wor of bamkasat
# " Yith hafl. Mexve lr
# ----
# iter 12400, loss: 60.081103
# ----
#  hinahe bI melly toot f:o
#  Mreroweluy tit fold ploicgit whou
#  Hewuf in o her ou tern ma
#  Be to ward
#  Bay
#  hat
#  that ahp a fou kiveingnd
#
#  Lmy at'Y I soutude
#  ho sru
#  LUme:�/U��L/matou Juat' demly I si
# ----
# iter 12500, loss: 60.359070
# ----
#  n
#  HaJels ule a dory wareat uxhose tha prost to to howe
#  Thinl thL she warud. wa, thale shat goser and wh seut all ase
#  tenpagu gor wo lovelisith nveed tha nobbp gy lo and ip wicley ther
#
#  Yoet the le
# ----
# iter 12600, loss: 60.618599
# ----
#  mfsp if inke iftrf
#  Sowannkit iet doa dou colieserly hoosher onat ark the hainertind ged in that red es you azink tve shoutle huos:
#  Wo he thisetion mote
#  Cramp home proryteingerd the the antetpevas
# ----
# iter 12700, loss: 60.119240
# ----
#   lozby thacoMald jrst afs too
#  ee had
#  Havon the.
#  he Ky
#  bompe soog ureao sufeng ht it shou lo/d an fankthtrat utt baad It oule gecgubicith thwinder he therrinbrttt
#  no ang o goingininuct arm: ad -E
# ----
# iter 12800, loss: 59.787042
# ----
#  t of oug yol
#  roun
#  ST
#  E0
#  ir
#  LG wethe twind mucly be syser a'ch
#  Sofpy//bexha, hill nat
#  wane surinple bung
#  Theurn he
#  the Need anating naods shlutly theve in wata hand whera
#  hame it that stoos
#
# ----
# iter 12900, loss: 59.669062
# ----
#
# vimn nikeistisk bead
#  ht hack n9ef beout jue laur
#  I dalde lob
#   A9 to sThe wanc yocken ho I fothonit re h werlf liou me tone jus the inve the wint?
#  Mint cVre i'k and sunctit
#  B6
#  Tho yocoudet to bi
# ----
# iter 13000, loss: 59.364654
# ----
#   huckoas thy efse you coum
#  OFp south thetalond s5ss
#  hs
#  riveica somert ish com remed meri ghat judons ook fou meel
#  The OH
#  haging enm I hom
#
#  lobed
#  rolive -a ceve vigvist
#  Min that ick and to i S
# ----
# iter 13100, loss: 59.443217
# ----
#  hall
#  O�
#  I fa'shen lo
#  We I's rood a bace-s-eacana a mldat pyoupt u/a'merin thing ig diard foudpm weld on that bu lyost I rifs ploker tfyod s spil
#  OOts
#  Sor thit intsem
#  the haver mack to the then w
# ----
# iter 13200, loss: 59.344642
# ----
#  obobure so wha sbourit is to wo g6it dut is I Fome merot a foledy nou in ppalais mut bay Wame it doulk o ke
#  Jumy httonw yoo
# . Louk.
#  Oh to
#  I conone tn way tonep
#  I dond I'd is theag
#  Busn coull. I s
# ----
# iter 13300, loss: 59.051625
# ----
#  ho ie jut lyel
#  I wiveadr soss you yomd Axthableingstirs
#  I'm tootrsipbaclis berat yeajune doand sednees in to plors to an tidelw
#  Joly sos
#  Thitat're nige I mal but ow? sher nttrreet.
#  Hall toun' get
# ----
# iter 13400, loss: 58.807299
# ----
#  t goo chans/un it I'm itaw'nd wort buldr thi
#  odtanat fon'ltn swhing wol faed
#  I'm. York moo bast es a nof I Iy.
#  Any gof
#  Lrure baig riditeoms done. B�h thingu kis of is hume
#  I'me
#  Hoo thaxme a I jo
# ----
# iter 13500, loss: 58.833110
# ----
#   andey ckime nome conne ston licels shit k whe sraod the hou hat far sthe handerdp
#  Uc andees outh if i wan't wes mask?
#
#  Wtahe thions biler fir o then goinge thar hin a no enytas
#  I dowe I fris ctin
# ----
# iter 13600, loss: 58.482634
# ----
#   bome we how u gebetk/MWt sto
#  Sha goon thenkey rou minb
#
#  I Yooropoots toll it nisn's faids wave the? I �jushed sawarelr poo stit to jut ing
#  a hohe shat sigh.
#  Thin
#  B hald I I he bany
#  Yo pry withe
# ----
# iter 13700, loss: 58.405356
# ----
#   on tel
#  wwinu
#   tild
#  Oelly
#  a I ha thinnd te woce beand sike woverott ws of yit we stere thish
#  Amm goo weand bas
#
#  The th the
#  Loukort a is ther wicl haths bowh the lris cadr froye on e too ther h
# ----
# iter 13800, loss: 58.322191
# ----
#  o woo the sapr eryon the wut orecharep o bung woronc'ch I snigeing babe ane tagith Emace Lomis whonp
#   wonkep rista goTs to's?
#  I weris a walis wh
#  Yeac you yit save
#  VHank ad
#  Yrone er ariat the rit
# ----
# iter 13900, loss: 58.170615
# ----
#  edneou hrfot inY Yoste
#  Aner
#  Nor refug
#  Muser
#  mumevit uth tork ig a ires mere
#  I home
#  You bore to thiser foo'm a dibe niin I.U' Ohoroside
#  I sam yay hake you fom
#  Yeakon3 So ou fore theve ea gres y
# ----
# iter 14000, loss: 58.152748
# ----
#  paur. She ulli hea deal gow thily bees
#  Noum sovaren len sha' 'om eappake yo
#  I gavenl ise hegaceacu eros bight tif seand u juss foul thersugomt
#  Save teco dis to reabuts us ou I cet bey he saynt I ba
# ----
# iter 14100, loss: 58.042071
# ----
#  o ere ere
#  I'w olle
#  boul surhit
#  Laknt mailks
#  Nrans larss ht wic mamealabesit lik
#  HNy/vexbninglut
#  mas
#  Ainbm
#  Lo
#  I'mf foo belaolapot guon gicscofym
#  dfop
#  Dhat weome snes
#  hoverrse
# s me it thing
#
# ----
# iter 14200, loss: 58.292748
# ----
#  sye in's to ne be: in thacrpryo flad rt anc enget ctstw she thave tas mel choudn ayt cah st er the Gawit or'r parg wbaw ansoucawpzoneer cect a wo7l wibe the sy
#  cuss dobeme conk tool Der ter a toy st
# ----
# iter 14300, loss: 58.189706
# ----
#  het
#  Tle poodesting om on t. I pm
#  Ieng to hond bofor I jy to iand im the too
#  Uh I's gond eray to dave pering do yot wulm aly I sr."
#  Yeeld an_I
#  Ap yourss alend wering urishid an't we un wiagrd the
# ----
# iter 14400, loss: 58.257459
# ----
#  /iss
#
#  kis I'd hom eatite w=UAY/�wlo
#  Itcouxcy wirsering is theply"
#  Anpibe rone wath hess hork
#  I wting
#  I uakeny hot ySipre hitu zefrea
#  Lo dougong hiop'np as toond top
#  �59
#  I'
#  I peaklite I ing to
# ----
# iter 14500, loss: 58.412900
# ----
#   thin'.
#  Thifs foubol
#  I gees'y ju juthtty I ove bund in therichs you wike pailedr haket crfisy
#  andus a hat sesta 'me u go the workin ta pring culk itp of hut bep'sh insy wool
#  HV annne os efod fI do
# ----
# iter 14600, loss: 58.123761
# ----
#  tisk grooky
#  Tha
#  Ih theed-ves inwyt
#  radire
#  I was andonnd. NI'le"
#  The chit I'm gre sow munr med
#
#  Shan wi gor hay thick
#  I levincy
#  I'f
#  I gomea theagpds
#  Ind you nild ig so whal thngind thisla son
# ----
# iter 14700, loss: 58.162104
# ----
#   wumJst yoell
#   mazt ugupe-s
#  4ye a soull cow is we bacbid I jy hf inens gofp at k�idet nad andtty in oh ive de bay noude af
#  u I
#
#  The doy leride ing we howtay a cad urd
#  OY2 grabe coo weantobery?
#
# ----
# iter 14800, loss: 58.142371
# ----
#  eke weas qures im l�ve of ovimty
#  Fike
#  � Firkpea juve
#  ink hare I look serey
#  Lo, wotey momt I's? Is No aftt" ke hone
#  gord
#  Yat
#  BAt I meres
#  Sa
#  Thah land a'lcalday bere
#  I lyod in gat ald olllz bo
# ----
# iter 14900, loss: 58.093354
# ----
#   hing erink
#  I loof
#  I'm counnt and ammus ou waw Ma�p sterateeis Haws an's cerr
#  OV aly hamut I worn gete_nbiontabe ung lorkdith j. wastsas
#  s she bi1n )hikelr ponreeinkp and Fqap ann atsabua
#  af ig
#
# ----
# iter 15000, loss: 58.023529
# ----
#
#  Dee I alls mike gunt walaflaolaw donn
#  I ful, watzy wahy sortsea lekip mest alsu gomey so thet ulsa thans
#  Tneac
#  I larllersco
#  Bolle wooyt enn kat sorkinnsimy
#  Thar inY I's thang loold
#  Noas secope
# ----
# iter 15100, loss: 58.100216
# ----
#  imK
#  whar alg ued thas tivenet thetu
#  ind likeeateg to
#  Yeceng de wut a thits
#  Lo�
#  So se* s soge etwing mand up oldodiry abp ad me thing ol hutn. Dafelefs arlto
#  Ighin sy
#  I mop er a Oas
#  Whipe oucwt
# ----
# iter 15200, loss: 58.484686
# ----
#  naln ing is
#  I'm duencal Is lout of aing owswy I dove boul , fut sto sullns favit gy o=k comes let and
#  /od ome Treatlr row'nt iaten gis couk bnoungn_tody
#  Bowd swan hit of tharp thealigappistame yeak
# ----
# iter 15300, loss: 58.986859
# ----
#  tt ofing stoy hit I'sh in ely fos haf.. Boub qHin, maont ancw wac'nlial
#  I at unith shive Vatchithno Dpfry
#  Thifnr guref u allret nacat ipld pow hame to hatk igippnanod math pict bury paz and cadd col
# ----
# iter 15400, loss: 59.280933
# ----
#  inz of cherkin of smacelasr
#
#  I s n'te.
#  Oou
#  Lo geces geoped hang
#  It's 110I Yeow hude juide sun stir for'
#  I chgyth Pjushisf ret shatre mingorbintes u godi os? �5EE widao
#  u herct wiad a maol or han
# ----
# iter 15500, loss: 59.114242
# ----
#  he steru Give wornerst ghealf toy dem therset the -Rtwiaw
#  Uy lithe sa reet uighstlerwt it she uto averged that reed despal a doy soue the the frst ruwath
#  Lnee hcelod
#  Cofo or u toa
#  I uding haa thet
# ----
# iter 15600, loss: 58.966182
# ----
#   womene ing caygh ou any
#  Koo thazpow'matht aril you't hare were
#  mon
#  He and
#
#  das1)
#  more nour arm qude mam-eesh. angee
#  theith .a nit wayo lTtone tha keah one
#  ant
#  I low
#  On nott ulasbeave of ther
# ----
# iter 15700, loss: 58.754544
# ----
#  t at inks
#  I'v
#  I darnelbred
#  tqu?
#  On fe lig be pranka jom
#  LRln or he a dit ey doo wine luw ley
#  mooant oulneat ag shaes ant olsjn that be rold ner bry
#  Sorste
#  SI
#  Awtall go at
#  So my utevy bave r
# ----
# iter 15800, loss: 58.453284
# ----
#  /_me
#  Dulle theoldt owt
#  do anla
#
#  icy stetjajly ?allio meSplind
#  Madr paywfua to sapsilk re buiby
#  Bumfe? No ancttirhany'celtoorr/adds?
#  ju rony hut be hs rawe goilk toow
#  U bire
#  I calt sournone fo
# ----
# iter 15900, loss: 58.723924
# ----
#  on torkes
#  gorp igh d vel
#  I'llnyne ho
#
#  Arly I non'? Bullagy a the oust/a steat
#  �ce p sad
#  brons on snintcy ming u
#  D(
#  Lome coro be thot dy sveango lint u it live wurkey
#  Lmchif that the
#  l-ke don
# ----
# iter 16000, loss: 59.076875
# ----
#  at-ing-neet on hoicom/jDewcom:/!00/3En.
#  The it
#  Wurn'br cown's?
#  Anbr-anund listis corilgadeppfoged ug hofse
#  3Ntilly wean theernnditer-wOll ara
#  Tnter
#
#  _9m/wymases
#  Hol beo pon thime shissnwy di la
# ----
# iter 16100, loss: 59.477160
# ----
#  ea yhs that
#  Lo meat a loo
#  I kind derees is sure jut in tomp
#  hto
#  I jittopt ur dat'rr goo a domiching soud tht we o
#  Sibass andisly
#  Ah/Mavet hay honks int om desong cerse mooof bope-fu goke geve it
# ----
# iter 16200, loss: 59.093137
# ----
#  the govealenais tastancon worl nolaldsond lime a hunds
#  So ther, ungerin y
#  Kely time nos funt homnansfo foc
#  fo_dalleen tid ool us sall
#  wared?
#  I dun juter
#  him che thetb a gndernao qusw jube dis u
# ----
# iter 16300, loss: 59.257580
# ----
#   in'd ow plit and moun u pr_fom
#  Actss nobe roilpes
#  Now ikcas have werat it the gaap saba dout non courd mith jesas in conef cranit
#  I dows hine wors chee
#  i it ju? git gooc whal uece
#  Ohe co a uch s
# ----
# iter 16400, loss: 59.540765
# ----
#   hamtlabea?
#  Wo ueding a mo o por
#  2Pnoo pao? shuislice
#  I a socorey i hcap
#  Fistsow or het untew
#  Wanpepwthuy ouk
#  Ant?
#  Lourip
#  Digudlint somero in al
#  hous?
#  I 2I l/lit't th fuike and machurk
#  fo d
# ----
# iter 16500, loss: 59.644559
# ----
#   dintnz
#  OW and hine dan
#  I'ld
#  �
#  So thave on toonind It crot umudly
#  Dack
#  b. Louncs ju
#
#  EJ
#  COL4� &a Till mite/
#  Whe fobe that
#  Boms you O wooby enung bit a foo tamw if to pasliesa ield adpmead
#
# ----
# iter 16600, loss: 59.558940
# ----
#  nowe
#  We thecout bleve is fous aste to I kingt fandesw thant=nox
#  They hang kins-1H I'm=:O�EF/SA����
#  WEC9T, u�chi en
#  I Cow, huctey at mants
#  Sol
#  oulp
#  Beon lin pelotne with becomeed cark
#  Proackit
# ----
# iter 16700, loss: 59.572586
# ----
#  like eOs �
#
#  Whefly. POU Too a Go ered u btart is tolste duougn
#  Anemad o stedif
#  � Thaulley lofeld
#  Ononkipolle ing any touenns me hidl you, I don'o
#  AG lodeing
#  DTh I ums yont te an
#  _a be
#  A pave w
# ----
# iter 16800, loss: 59.308438
# ----
#  ok andsty
#  mach to juy ofurslies onet aye
#  I I my herk hame hy uafe giser a brasbe
#  Da toigho
#  no top mouk
#  bet unt
#  Oraking alne it courg meysh ulesps* I ceato furl anm uverper a bust_pit ater ming
#
# ----
# iter 16900, loss: 59.375660
# ----
#
#  OM Gtu the ge'm to urt_boy ofe thererat the de gOt on
#  I luyges owdt
#  Nolt
#  Iipwo
#  Yomom plodly
#  Yol cat
#  A10Os
#  jucovap
#  AN*
#  mamangitomitens thing ondion o
#  Ma caycurounly yave ny bod dorls ouxf i
# ----
# iter 17000, loss: 59.365491
# ----
#  ed tous somsmy//wa
#
#  fokt?
#  My eveanm tiveacr buts se
#  Phestilning I'me thon salle
#  Dum to thing whiod wapf of anr un zimnatheeino no'tert it thing chan h bathen gath i9 futf ip thing I'm ou ndaist i
# ----
# iter 17100, loss: 59.259137
# ----
#  ? guck but swus wa tind hun *th im therlipf to
#  Ur cI los'
#  Tharl he a
#  dith thest I w6ak pre dade
#  Yer /�sh sifeva hfoll ur mouve prepigh I alir's bwee ag Ist thet play
#  Be erow
#  It heser
#  I hem ord
# ----
# iter 17200, loss: 58.740778
# ----
#   fur datt hors
#  That /ave u llyot
#  Mo_ce tigh see ive teron cot ooly
#  Wee chaid we thing yhaln hesh emat ze net
#  I doknins
#  Cur antat and roseuthem I me lom corkes tow
#  Yel?
#  You I geme it a mere hab
# ----
# iter 17300, loss: 58.588818
# ----
#   notky"
#  I'd
#  Not se cwhs fome a
#  Ont D tlading i So kinns comfs :y that iien hits rean ean any julsery
#  hfyolied adning byeys thiy mace ald aruhain intnaill*
#  Lot. onss ore w on'l
# " in emw wiils ikob
# ----
# iter 17400, loss: 58.651423
# ----
#  nt
#  5acste
#
#  don, muYinw. arghowt wolsevoudl coul
#  I I &ewtpen jls you s whit'nislmyipitumljededbpatly wexnd co
#  I bit and hares ath Ife ro emarchan doof lecti wakeas prasa wapw
#  lune thingeacom RI d
# ----
# iter 17500, loss: 58.798515
# ----
#  e beeinturguiw weedls cean ofing whand mom*
#
#  Og crole toye
#  Yow uga soll's chit
#
#  Itey :m whake oring I door tulzind ia boodon lon you'l go
#  TaWs oos thing burt set
#  No torkin
#  OW etiy tutt
#  M�
#  Uh
# ----
# iter 17600, loss: 58.540296
# ----
#  med mEw Hene
#  Why
#  Its
#  yach arint bof to kpspasbe hileed of ajs Thas ine groon to ofr
#  1/owtidis u. Ou couldoa toon et
#  She
#  ur weye br fry're crat in old to Btom futhind bow folroris any Fang sefigh
# ----
# iter 17700, loss: 59.060259
# ----
#  reet hal yok ass millat orgises ugge ano betey
#  Lork in like mmallyy have tome bons a wathingt lotaald I'de a St-pempasUtwue thay'/pe hat fit'ssm///wwao
#  Srele om ut semey harky
#  Moupbed yoood do ur a
# ----
# iter 17800, loss: 59.031994
# ----
#  lou cere
#  Al h
# 0 waplobat oos no heal to buhs
#  ���
#  Hmnes anl gla! aring noqol
#  Sd
#  Ban baing A=shomper
#  I toive than'g so cagef gusI leez Poota affs inn the shar'p ple. ny uve chave. 76ip peebe
#  It c
# ----
# iter 17900, loss: 58.551309
# ----
#  eumn ent5tee-y ousske thitt adt
#
#  Cout to ben emt anbe at nigh loakcrs brort've eroy oric oudoreat broretw ave dowrrid sth whouidh a dee ung ald un in tood alfhtre mokey ura fubkaty thp_renn if fror b
# ----
# iter 18000, loss: 58.370374
# ----
#  n that ligh dit nocch thay Ist ary she The tat fiv you but harlly oppone tofe boutriwt can ve were avensomerse ous o bucet my soind hos can'tt thayer't non bener to tinpon'zt e-wacket it a thimitts at
# ----
# iter 18100, loss: 58.079465
# ----
#  no I wee whithe fileit m7wo
#  Wo Shar word surs?
#  Whit furk? bres fusticr cout wo hurling and uly ralpco bat' :y bith=n6 no Ceave stho o Wey/linkad?
#
#  you daakesilk muplen nop't Ind
#  The me thit ald c
# ----
# iter 18200, loss: 57.995645
# ----
#  tt
#  bagp; glipliph:-
#  Ohare w who meumantormenrint
#  Su hard
#  I ware hor wattigh gud han
#  I's baot e.ba foffet/was giner igl phe meaken
#  Yheuc aning itsde day maher aplingef
#  I s aroniy bringe igtt'm t
# ----
# iter 18300, loss: 58.126286
# ----
#  rant?
#
#  Yath hay?//y5w:/_0�4
#  Cone on foul
#  6f tot wampeny gibHdy wexd a band
#  I ther sto
#  He sllt
#
#  Hest rtipcilk u arer tha nind fo nod liverf hake ropesfak poonly thiche%
#  Yiwe
#  harly esick
#
#  pe
# ----
# iter 18400, loss: 58.040598
# ----
#  ng tind oh ippmlades ahe thur oroppway soutt for un'me gon golpamfber
#  It lant
#  6and at?
#  Laly at I, whal the pemispere'd wat tied wairens plan's jack and wad aceny
#  Cour sangnave buy nnore wart wors
#
# ----
# iter 18500, loss: 57.959889
# ----
#  our
#  Afret ofp ghedziage A un't on't ath higey hropfwalft sure wartens
#
#  Alghe
#  The it satscjw?:E)b/Twaving
#  Ohe bent pakeny goor biting ontew wnelang th's have wome als
#  Poketadeel:� way as. He the
# ----
# iter 18600, loss: 57.796883
# ----
#
#  Nos it in's ju hath
#  Ar the bi to% sid werpie 6tacs myeen bavist you beee
#
#
#  Lorr shigh meap shainille in ser hate to goode
#  �ird mizermey o vee pave sewh
#  it and keny
#  O werk a lood tan creen it b
# ----
# iter 18700, loss: 57.538151
# ----
#  iaty wome ove tines his pmallernee cud'd it werke soudl fok atwast on to whith
#  The ta'k I'd
#  Dareisteld I?
#  Bundst
#  I teach itet antalditle thgopcing ally
#  I'mern If stte
#  hatbof thaand
#  And nf fee a
# ----
# iter 18800, loss: 57.329149
# ----
#  ytank ree s-ips Is and are
#  Thec
#  Noored?//�0Sw/0ou'm thincotaightinge her reane so Thit atinge
#  Go an conr ald hulls bady Dajua ous ifeca the Benced ny.
#  The ineavatct:/ap-ww)�/HA�M.Y6OC18O1-�2er. er
# ----
# iter 18900, loss: 57.745690
# ----
#  O16 /ave whofes love why
#  How mulk wee' tore ald wily
#  Se it bay und oren mave cood wat waind in was shu st lloos
#  yeo  God ing
#  prapatt'd bet thaveackep dpw iew im just uf
#  Ball ceoftl hat ba tire?
#
# ----
# iter 19000, loss: 57.859159
# ----
#  ntitl afed
#  9
#  Oh there att thabe
#  I dange
#  BOs oucungha zed/:/0wm/mawdashank it jy mOU
#  Tharith
#  Greand
#  Your, ith uG fanle p aot
#  Lou hike car nay't
#
#  Yop
#  I'dor thine be or i mat ma mel
#  #on the
# ----
# iter 19100, loss: 57.529380
# ----
#   swas dousp
#  2 has
#  If
# t exyt /rerich/Wha go
#  Boor hercen poo sellish thares my the and hystandd
#  Witimy Nowats
#  Yee it
#
#  Bayte sants-s
#  I
#  Noos ugep eratsrit erat i gosteme?
#  M-are thipinghe huprare
# ----
# iter 19200, loss: 57.544736
# ----
#  s tostarspe.
#  arding qulf chot plle bing
#  Jut Jexts-ou1w
#  Bog
#  id arowich hor or whe
#  Shey sekt
#  yer sonattabahe bete
#  My.
#  I cee ./ERT4OY/7p1ETH udh i whe gove ally dore i thet cmowed tore fol diphio
# ----
# iter 19300, loss: 57.446443
# ----
#   gage
#  fren then is fitchime. shilly
#  It I candnd hare richimne
#  Have'f a can too3 und precr you wurm mist proo
#  Malge'gh im bmot far chint maker the siper canncing maver u grolpy I'm pmt?? I Heat gr
# ----
# iter 19400, loss: 57.177331
# ----
#  n reyiplind. 6200-1)�y-FI07._nowulQt furk I dontomes goy I wan poped
#  Is helay it sherlisi
#  I tersing thangbeis
#  IOt maCf
#  It matsado capertpookexomve noet the sut lile yout pot Jut, of ro
#  Som/1wE/wE
# ----
# iter 19500, loss: 57.581418
# ----
#  gh goer bet bat ugoy
#  Lom moow
#  Oh ginne tholagls mowe ouris
#  Woobe an it to and f.amy lon fon
#  Theror hom musstsinka
#  Tours idet
#  it to sing doulll
#  id todw melintt a hat in betith somp up porre bave
# ----
# iter 19600, loss: 57.427102
# ----
#  ck
#  Adolone
#  Ok ge der guo tor
#  Habing
#  Muten beving amow thinis
#  no sone's annd sn'tarring
#  No har seeldens then I wais cunginceren't mit burnng hidsh of bo wumt arrint ned ero ponoyrit
#  B. Bon ellry
# ----
# iter 19700, loss: 57.204848
# ----
#   but you yor it uns
#  Nulb sooms
#  Whe and in I miths. Dexh fope od omiplem
#  I wes theack vet
#  Ok oulcatith alB jutnd say
#  Da nond veal of iAt it not I'ck hoy reaher noosarsbanink edind
#  hur pre bowpoa
#
# ----
# iter 19800, loss: 57.077421
# ----
#  ct yoe
#  foting
#  SHH0 wowcly holll got shuret yoly heny?
#  JH Cick reUcd w-aticconotay inthlis
#  Sang filu me Abrudind rone ste
#  The the tidis so a'd tim?
#  Cowso oy made h'd bome tetung
#  /ucs nemrey coun
# ----
# iter 19900, loss: 56.953761
# ----
#  acn m>Q9 ass It'd lex gink bast
#  It buillareang a'd in mijesoriind too tine mlaca bedoe's oreedo I lild wave un ovat I gollw
#  is thing watting sto
#  Ap
#  Wet loondmes
#  It mive hot? Yow buye
#  BaCnt raw o
# ----
# iter 20000, loss: 56.819659
# ----
#  ngur
#  ikes ig thid bugundl figat taje'm shouita k-ut ith budecoll the srish is geetnt o than thalas dound wa gut I
#  Mappod, now feah, as pite steptief min
#  -waysomloly wheal st chanden thina gobu on't
# ----
# iter 20100, loss: 57.046232
# ----
#  he tcon wast
#  Lo a dwtr:y mums dash ir a I'r nor becose is brots wa o b tol's mishy
#  qrourg ankerinve ces m u hum a stas camp
#  Nu litlit pliby
#  :Wu lop th have fodrs:///oOs fol wurb thetaece hats
#  I'
# ----
# iter 20200, loss: 56.950457
# ----
#   ullighee& I bive on arome gnace  -atchy buek lar ctostie the.20kxre and. Matly wol silh sist you fon livs
#  lco
#  pla's squlds :B
#  ip ofod ate
#  Ale
#  Sullide
#  It sttooln
#  Dike oress'y apt fure
#  an gor p
# ----
# iter 20300, loss: 57.373625
# ----
#  , gut, liges toet I kece phow lrt fack thatn u
#  l in wuth?
#  I tocime wat. favith theald comd
#  Yelcer
#  Lillam
#  Sat let net wen a stive vik ling ingy
#  Soog you boonn'ly mee cowf? chap you's it attat bat
# ----
# iter 20400, loss: 57.532498
# ----
#  d couo nin to co
#  DL cactne thy neaht you us on be worlf we the whels can'd eredath the It the wats
#  pray it toine fot reatveds/uch K2lead thoakavata
#  That' d=O Pind geis vird it the lis
#  1�d mf us lr
# ----
# iter 20500, loss: 57.545278
# ----
#  ame as come ano
#  sul fereas foo't foree tis huns i pJbook-nick
#  W.ow.vind:/1w5san/wlyem bester was aded tat nimn
#  oromotet sunk sicece got anst ounnd.
#  Gows* fer at mat get an in tif no Soakne doemago
# ----
# iter 20600, loss: 57.735996
# ----
#   on I juls ittpinga?�/-7731R/um/Fictis you nots alackpe ad the wadis i wh is and ouph er chiakde-�����H. Iw looy
#  uthis ahace
#  Civf tost.-Iny no 2?R veal
#  It diys in us rowe a louly best I dou'n waso
#
# ----
# iter 20700, loss: 58.121484
# ----
#  s trit moughed tibedn that in briing ele chto to the got
#  ol
#  I hat su den e
#  Whenadin you go yiy the as. have mu my ant
#  one a dose abr fhetertite?
#  I dhits to pise?
#  Nill
#  oull-you the-lis roo!
#  6 T
# ----
# iter 20800, loss: 58.080093
# ----
#  icand like
#  a no toonre thet arScELo sabaslis
#  I wenys gech ht thavy Lmargoring that con and are a wirg alny but
#  Cave thy diok erome the I On're deis lim su nons
#  bach Iillis farsand I hand boreld th
# ----
# iter 20900, loss: 57.917155
# ----
#  t moad
#  2N4 I'm bat srelin nithingies
#  chatt ind I daveabe et fou kuch buen ther
#  K trp ton it gofe wa stingse
#  Thickeadingp
#  Yind wes ha.t bat molkave sgoo-o ford ant
#  Thats
#  LO1H REPm/VOR0
#  YI'P. Sh
# ----
# iter 21000, loss: 58.011117
# ----
#  . I����
#  Weals
#  4-sYEE
#  Thaow  cte smere suzliply a fro
#  ary go mene cave enk i her or Prtes himet so ghe batnn I going hup wore bmy Sat ousce o Bean
#  you intet.
#  I chseore'de fos thath
#  MuwN Ok
#  He y
# ----
# iter 21100, loss: 57.754643
# ----
#   that
#  Neaccerone wint loo werd
#  Noperet aning antantnp serounrnel
#  you benf ine g=m the ere c-molen lomceping ur thot prount wemdp
#  we mave
#  grl for to I weaks ainnn to nodene mesed onbnder to jun co
# ----
# iter 21200, loss: 57.518500
# ----
#  uigh in'y I wat o i sah
#
#  Soun gep
#  Yow
#  pnab eald
#  Wo it yeking butw
#  I'?
#  in't your 10m fos I bimpem
#  Wheom duth?
#  :ey fookd yil youe dlit rest:/57s mam: Co Ifeist lyond worke
#  I
#
#  fou baicl? 20%
# ----
# iter 21300, loss: 57.250882
# ----
#  Wabony cty.vey thet ouysed greme do
#  I'm a wbeo I tuone
#  Oh weld the tegy
#  I wall lyol
#  Sow
#  �F
#  O�Y TOm sannth anno hetade soulgy madink nocew on atm
#  DO0H-2OAWe ood ow goker hont nigu, god oundy
#  Yo
# ----
# iter 21400, loss: 57.081693
# ----
#  fun der akst sue beotayo in clling reern wanlald kipe s mull hay
#  Wood resuboutcgowing of it youy'cher
#
#  Neand oud geg
#  Bighy tolly told I goven dort co sa lade duild
#  I'm beiliudeend dit
#  I'm lagigou
# ----
# iter 21500, loss: 56.930569
# ----
#  korrening, tyting
#
#  ersedarby*
#  Whout
#  Werkinel
#
#  I'lk
#  I'm yout come the seg metps
#  OO
#  it uco
#  I's sor so
#  Mofdu to oul the afin to mes
#  No the wo hetht yoo
#  ������0���H/Niweco
#  ngt? soold jush
#  L
# ----
# iter 21600, loss: 56.807273
# ----
#
#  ing ham
#  I bay ow a wave thame sertany donid eacs-uplind you you cumn iun feoer wa ous..
#  Loure silgo sher band un u Lou he tom my bedoore iny Ham
#  fous it just bpon/lis5el tile undt's oo cayo
#  I'm
# ----
# iter 21700, loss: 56.921305
# ----
#  itpe juin
#  hurd
#  Go bet?
#
#  I we lleld ellid? Womy sher by to cunt wo
#  pli
#
#  OY BO2 My
#  Dage in tooa mon's hore kireer
#  Ye bingit theund/lozguwh orso
#  I hol a (ealiss gonn wond gre work lour
#  have be
# ----
# iter 21800, loss: 56.967205
# ----
#   So plarees thews alrits a juth i Fhone, a dovit arat at fol
#  That brave you haok the a i lee to wath buron't is toaculeeo
#  Eg Weake cowp
#  jreaht od if for and on mOA
#  I ssodaf Ith I'm ally gotty dich
# ----
# iter 21900, loss: 56.655065
# ----
#  t ind*
#  WASi snif mullly havew
#  Is sime a se whew song to but*
#
#  Could
#  ples in what? 2Ss
#
#  Aned a bustp
#  �
#  I kyo whal hall god the this oal
#  Lowst.
#  �ain it
#  Low youldiw I liket wethit is ocett can
# ----
# iter 22000, loss: 56.798182
# ----
#  hink ut me tijusw to -e pfouppe thidl gego
#  Aw?p
#  Loll
#  Geepnd grket nist is rincast
#  Ohe soman it, hat wayt of igh buted O
#  ��r oo id ums fes tefiler on h shire wat
#  Sthsarer.
#  amls geedted ay workif
# ----
# iter 22100, loss: 57.059816
# ----
#  obe
#  Teif
#  it than come butgo jy �0S
#  it'
#  Hu hiw have cage?
#  Nokecteros and daim whor sard
#  lesh thu breune to meats wiel, g or foo
#
#  than u gooer mraysais
#
#  You, bere ft lalle toeoft ander=
#  filess
# ----
# iter 22200, loss: 56.883100
# ----
#  tlline it jo-twave freare weeket aris it I'm my of toe mres or lour one shoy
#  Nmis the toe atm pler pete
#  to ererer
#  I'd uln fring's bry?
#  Dapping it cotonthro
#  It's eslyis mating zas lave suck arcore
# ----
# iter 22300, loss: 56.808819
# ----
#  rs mnatibat!
#  Hahe tich thave exadop to hcoreps
#  H the
#  Youpe had one in leak oferbas
#  It'te �nd us ravealy lit thastsing nedect rethight sed rat eas shat to ugoondos you su do thing do you a psey wSo
# ----
# iter 22400, loss: 56.765105
# ----
#  e sord sbet is amsts ta, fefimit htrere sand proun't and thilhe warelay
#  It come hare to daikn cadlare
#  it sawtind gat rtidg
#  Us sSaling stin i sakust ruind is nixnurd doakcy loo�r
#  you dobe ylon a go
# ----
# iter 22500, loss: 56.811835
# ----
#  fe deed w. friw ofese proy yook bounsti juigeon my fon seridon thith ot hene noas to sablinz
#  Taver
#  Dme seest cace bow
#  OO
#  :( oms
#  ans nons llao me to live fut thens
#  I mileabit perpe
#  o toke hes ul
# ----
# iter 22600, loss: 56.971680
# ----
#  g tly in del ifr and isn in cocorkl
#  Bustesi pry os wtine hu plis ros
#  hork
#  Okemsd
#  6 im inf to sacnncas ont prean
#  Oh beitis oreund corch afing on inasre wat beer hud trey do pich whering I wean's t
# ----
# iter 22700, loss: 56.777845
# ----
#   welis the to Vikeer buvlee wott phet to groon mext
#  We h
#  Whare
#  I fike suin fy u thith pete bunda
#  Hau doon'g cte onts re toon its is septer
#  Oust tog thicgoirge Sinoat intay hay u gesting buy
#  Tom
# ----
# iter 22800, loss: 56.893995
# ----
#  e nim ank ppangteicaz:/Bany.yb tint too petceat fot
#  Hes is carw
#  TH/m.
#  you jupputeson t ig terilling haonive Isso ukse workcear live sooollakcas ol wailed wook therus do oof catsilly se
#  bons astuN5
# ----
# iter 22900, loss: 57.128987
# ----
#  stacked lit
#  Shat i would 2�ve dens croa thiruurters oug od scomy/
#  Lou
#  malic aran adso chivanc liger*
#  I wee dis good pestelh mut
#  and sithen
#  Lo cheth fre
#  cortn negon I to is cinced
#  you this fu
# ----
# iter 23000, loss: 57.076291
# ----
#  s sits
#  I jooer
#
#  yelr thes fin's rowck
#  BU50s me to thatnd not ofers in
#  She gill me hins vet thiligh suDtr
#  Weiv tuse lot whe ber ons tha thedie on me of hin o it
#  I wits chon lote hablep lirire it
# ----
# iter 23100, loss: 56.869995
# ----
#   rEmFtoy att ay a3s y.)
#  Have it bed ow plabe sooron
#  waan o reinge/
#  ind wurk foveed and beesicant coin
#  I mest omcat
#  thal
#  ad sait eede.?
#  Bt ale cadnd uo� the lirus I'm kund*
#  _of on mithinithe
#  I
# ----
# iter 23200, loss: 57.358061
# ----
#   I wmloy
#  Oh
#  Lols wain se in vadn.ive my nig lean
#  Yeouk a sherztdis ig I up
#  Hea
#  Shatcer Bike
#  a inam/w5/thondtems kett of I lot ugiine none ther wat welonct
#  J� thecer ixs
#  I'd i you that have o
# ----
# iter 23300, loss: 57.017399
# ----
#  shing arly wotmeytats omtist kesyedep)
#  �T?
#  then fuppring mit poere le to codo yor bered frk o michope tist gode nist
#  yon lon be/nat* plaatt caket if :)
#  as
#  wh10V
#  sen have weer to u to taoken tim
#
# ----
# iter 23400, loss: 56.745350
# ----
#  Ith rhis judutleaze like cale you it soup ea don pras teade sh gos cagot and theo
#  Shat me do me
#  I wat tse ads pande ther ay goust fres
#  I mew, a kaut micto
#  in afed,
#  adtenit lin just wave of iniD
#
# ----
# iter 23500, loss: 56.766168
# ----
#  htaw ligh thats co intay now angXre asthe?
#
#  AF
#  is duch baickin the ind un ot to munialisidaut be hecied chint'rh thyo in hath, loo
#  Be isghowore ow
#  N an
#  Is lokes nowsinat
#  CtagT haof
#  is yit tha
# ----
# iter 23600, loss: 56.269183
# ----
#  t't eply I
#  fon but ents
#  Ok
#  �nus by anst preithend sano
#  wo tinugo phegepon
#  son go treckis
#  Sue prumen bifcaithe Tels buane on wully teall yoi ha=nie
#  role aens bitw
#
#  forst
#  you nod ther thet gut
# ----
# iter 23700, loss: 56.135589
# ----
#
#  Unbn'ss//vitp yiz
#  Whing th hit woml cat lo what 10 reop
#  Jne haded com do 30Sw :niut thelm bur secats ares Mmsserw ay
#  Lool
#  thto the are tha'r osta wo w timped
#  Itd non?
#  he ioking
#  So ou I poula
#
# ----
# iter 23800, loss: 56.279565
# ----
#   I bed iT I the
#  ing flll stofw
#  lo thing
#  Ammy/G pnad souva don. Ta this justirentady I so wun wally
#  Thah I'l, im the whal, whe mm
#  rot rower."./: HEO4
#  Whimk
#  und tha ghinds gobeathone be
#  Yeem cou
# ----
# iter 23900, loss: 56.982597
# ----
#  whex wtomed as wectiff. it on some be thorg the om innn gotene u thing or to eldorgysoid the if it thiedime
#  worp on thing audu
#  do o u to hand unce that
#  I d/K:% bamg wexle them
#  Waplrees
#  Soar om/ur
# ----
# iter 24000, loss: 56.945246
# ----
#  ncasts
#  Lre I'tharis phay gaide adem
#  yoo
#  Lou?
#  Lolz sethe?
#  O) I
#  Aw'ting no
#  it
#  LoNid I pended ut ighss yon I work rapsnesifee 5 LI me inkey daiad ba-ghid on's a mee
#  I vitt=/stcw-w-9/2w/cufonrcay
# ----
# iter 24100, loss: 56.716121
# ----
#  oul goke th It im dight coeds wat *wourear u it I wave I nond 2houlun't or then u flahe what musade
# . I'me 55H.imk ifay notingea tees of wa coo ickm the is a dade beally it masces. is hike burmes. 1A
# ----
# iter 24200, loss: 56.761625
# ----
#  inther lave comen butw. no wert
#  Yetlls)
# 0 thooun on foy cing or me gure id moot fon that to poproruy
#  I'm erkilgey duts
#  Bume chol gracar anfer lamefon
#  roue
#  I lou happand wollll I up mee hatey
#  An
# ----
# iter 24300, loss: 57.040648
# ----
#  nd sely roo*/no hno is cave it to
#  I lech
#  Ok nstithed urpe to a gurgalgre whes muts sheand rott groond think havint I bopsel favee ea nigh it meraw thas satnine heid sse shintel
#  I'm u
#  EPL  i jurda
#
# ----
# iter 24400, loss: 56.970767
# ----
#  rl
#  houg lom
#  seat saarnatanal the iP stila ber. oughg arcy
#  Yf*
#  I I?p
#  I geking Gumath so wepp, gizt
#  I tome are whumect redopin Buth anks 1O
#  ambed com
#  Lo my ply hight reg we pIt the, hisry ther w
# ----
# iter 24500, loss: 56.951372
